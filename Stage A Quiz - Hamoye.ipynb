# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd



from sklearn import metrics
import pandas_profiling




import warnings
np.random.seed(123)
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("/FoodBalanceSheet.csv", encoding = "latin-1")

# %%
df.head(50)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.head(30)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.tail(20)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60923        181  Zimbabwe       2680    Infant food          5611
# 60924        181  Zimbabwe       2680    Infant food          5072
# 60925        181  Zimbabwe       2680    Infant food          5911
# 60926        181  Zimbabwe       2680    Infant food          5301
# 60927        181  Zimbabwe       2680    Infant food          5170
# 60928        181  Zimbabwe       2680    Infant food          5142
# 60929        181  Zimbabwe       2680    Infant food           645
# 60930        181  Zimbabwe       2680    Infant food           664
# 60931        181  Zimbabwe       2680    Infant food           674
# 60932        181  Zimbabwe       2680    Infant food           684
# 60933        181  Zimbabwe       2899  Miscellaneous          5611
# 60934        181  Zimbabwe       2899  Miscellaneous          5072
# 60935        181  Zimbabwe       2899  Miscellaneous          5911
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.shape
# Out:
# (60943, 12)

# %%
df['Area'].value_counts()
# Out:
# Kenya                          1560
# Egypt                          1488
# Nigeria                        1474
# Côte d'Ivoire                  1467
# Senegal                        1462
# Cameroon                       1460
# Uganda                         1458
# Zambia                         1451
# Malawi                         1447
# Ethiopia                       1447
# Madagascar                     1439
# Mozambique                     1427
# Rwanda                         1426
# Angola                         1424
# United Republic of Tanzania    1419
# Congo                          1413
# Guinea                         1410
# Burkina Faso                   1409
# Niger                          1403
# South Africa                   1399
# Zimbabwe                       1393
# Morocco                        1393
# Mauritius                      1378
# Botswana                       1378
# Ghana                          1354
# Central African Republic       1344
# ...

# %%
df['Item'].value_counts()
# Out:
# Milk - Excluding Butter     1262
# Eggs                        1142
# Miscellaneous                911
# Cereals - Excluding Beer     714
# Oilcrops                     706
#                             ...
# Grand Total                  135
# Animal Products              135
# Vegetal Products             135
# Sugar non-centrifugal        121
# Population                    90
# Name: Item, Length: 119, dtype: int64

# %%
df['Element'].value_counts()
# Out:
# Domestic supply quantity                  5295
# Import Quantity                           5139
# Protein supply quantity (g/capita/day)    5023
# Fat supply quantity (g/capita/day)        5023
# Food supply (kcal/capita/day)             5014
# Food                                      4941
# Food supply quantity (kg/capita/yr)       4905
# Residuals                                 4655
# Export Quantity                           4403
# Stock Variation                           4232
# Production                                3881
# Processing                                2010
# Losses                                    2009
# Other uses (non-food)                     1732
# Feed                                      1319
# Seed                                       762
# Tourist consumption                        555
# Total Population - Both sexes               45
# Name: Element, dtype: int64

# %%
df.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
sns.boxplot(df['Y2014']);

# %%
sns.boxplot(df['Y2015']);

# %%
sns.boxplot(df['Y2016']);

# %%
sns.boxplot(df['Y2017']);

# %%
sns.boxplot(df['Y2018']);

# %%
# most frequently occuring class in the Year Columns column

# %%
mode_value = df["Y2014"].mode()[0]
print(mode_value)

df["Y2014"].fillna(mode_value, inplace=True)
# Out:
# 0.0

# %%
mode_value = df["Y2015"].mode()[0]
print(mode_value)

df["Y2015"].fillna(mode_value, inplace=True)
# Out:
# 0.0

# %%
mode_value = df["Y2016"].mode()[0]
print(mode_value)

df["Y2016"].fillna(mode_value, inplace=True)
# Out:
# 0.0

# %%
mode_value = df["Y2017"].mode()[0]
print(mode_value)

df["Y2017"].fillna(mode_value, inplace=True)
# Out:
# 0.0

# %%
mode_value = df["Y2018"].mode()[0]
print(mode_value)

df["Y2018"].fillna(mode_value, inplace=True)
# Out:
# 0.0

# %%
df.head(50)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         60943 non-null  float64
#  8   Y2015         60943 non-null  float64
#  9   Y2016         60943 non-null  float64
#  10  Y2017         60943 non-null  float64
#  11  Y2018         60943 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
df.isnull().sum()
# Out:
# Area Code       0
# Area            0
# Item Code       0
# Item            0
# Element Code    0
# Element         0
# Unit            0
# Y2014           0
# Y2015           0
# Y2016           0
# Y2017           0
# Y2018           0
# dtype: int64
